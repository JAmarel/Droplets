# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# the following line only works in an IPython notebook
# %matplotlib inline

# Optionally, tweak styles.
mpl.rc('figure',  figsize=(10, 6))
mpl.rc('image', cmap='gray')

# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series  # for convenience

import pims
import trackpy as tp
import os

# %%
from scipy import ndimage
from skimage import morphology, util, filter
from skimage.color import rgb2gray
# Out:
# C:\Anaconda3\lib\site-packages\skimage\filter\__init__.py:6: skimage_deprecation: The `skimage.filter` module has been renamed to `skimage.filters`.  This placeholder module will be removed in v0.13.
#   warn(skimage_deprecation('The `skimage.filter` module has been renamed '

# %%
import skimage
import matplotlib.patches as mpatches

# %%
from matplotlib.pyplot import quiver

# %% [markdown]
# #Load raw image sequence

# %%
rawframes = pims.ImageSequence('E:\ActiveMatter\ShortPNGs\*.tif', as_grey=True)

# %% [markdown]
# Images must be greyscale to track. Otherwise the image is assumed to be 3D.

# %%
plt.imshow(rawframes[0]);
plt.title("Greyed Raw Frame");
plt.xlabel("Pixels");
plt.ylabel("Pixels");

# %% [markdown]
# #Preprocessing

# %%
def crop(img):
    """
    Crop the image to select the region of interest
    """
    x_min = 45
    x_max = -35
    y_min = 60
    y_max = -300 
    return img[y_min:,:]

# %%
def preprocess_CropGrey(img):
    """
    Apply image processing functions to return a binary image
    """
    #Greyscale
    img=rgb2gray(img)
    # Crop the pictures as for raw images.
    img = crop(img)
    return util.img_as_int(img)

rawcropped = pims.ImageSequence('E:\ActiveMatter\ShortPNGs\*.tif', process_func=preprocess_CropGrey)[0:10]

# %%
plt.imshow(rawcropped[0]);
plt.title("Raw Frame After Cropping");
plt.xlabel("Pixels");
plt.ylabel("Pixels");
# Out:
# C:\Anaconda3\lib\site-packages\skimage\util\dtype.py:111: UserWarning: Possible precision loss when converting from float64 to int16
#   "%s to %s" % (dtypeobj_in, dtypeobj))

# %%
def preprocess_threshold(img):
    """
    Apply image processing functions to return a binary image
    """
    #Greyscale
    img=rgb2gray(img)
    # Crop the pictures as for raw images.
    img = crop(img)
    # Apply thresholds
    img = filter.threshold_adaptive(img, 400)
    threshold = 0.6
    idx = img > img.max() * threshold
    idx2 = img < img.max() * threshold
    img[idx] = 0
    img[idx2] = 255
    # Dilatate to get a continous network
    # of liquid films
    #img = ndimage.binary_dilation(img)
    #img = ndimage.binary_dilation(img)
    return util.img_as_int(img)

frames = pims.ImageSequence('E:\ActiveMatter\ShortPNGs\*.tif', process_func=preprocess_threshold)[0:10]

# %%
plt.imshow(frames[0]);
plt.title("Thresholded Frame")
plt.xlabel("Pixels");
plt.ylabel("Pixels");

# %% [markdown]
# #Custom feature detection

# %%
img_example = frames[0]

# Label elements on the picture
label_image = skimage.measure.label(img_example)
fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(12, 12))
plt.xlabel("Pixels");
plt.ylabel("Pixels");
plt.title("Located Particles")
ax.imshow(img_example)
for region in skimage.measure.regionprops(label_image, intensity_image=img_example):
    # Look everywhere, but skip small and large areas
    if region.area < 300 or region.area > 7000:
        continue
    # Only black areas
    if region.mean_intensity > 1:
        continue
    # Draw rectangle which survived to the criterions
    minr, minc, maxr, maxc = region.bbox
    rect = mpatches.Rectangle((minc, minr), maxc - minc, maxr - minr,
                              fill=False, edgecolor='red', linewidth=1)

    ax.add_patch(rect)

# %%
features = pd.DataFrame()
for num, img in enumerate(frames):
    label_image = skimage.measure.label(img)
    for region in skimage.measure.regionprops(label_image, intensity_image=img):
        # Look everywhere, but skip small and large areas
        if region.area < 300 or region.area > 7000:
            continue
        # Only black areas
        if region.mean_intensity > 1:
            continue
        # Store features which survived to the criterions
        features = features.append([{'y': region.centroid[0], 'x': region.centroid[1], 'frame': num, },])

# %%
plt.xlabel("Pixels");
plt.ylabel("Pixels");
plt.title("Particles to be Tracked");
tp.annotate(features[features.frame==0], img_example);

# %% [markdown]
# #Link particles across frames

# %%
#search_range: Maximum displacement, the farthest a particle can travel between frames.
#memory: Keeps track of disappeared particles and maintains their ID for up to some number of frames after their last appearance.

t = tp.link_df(features, search_range=11, memory=1)
plt.imshow(img)
plt.xlabel("Pixels");
plt.ylabel("Pixels");
plt.title("Trajectories of Tracked Particles");
tp.plot_traj(t);
# Out:
# Frame 9: 5 trajectories present
# C:\Anaconda3\lib\site-packages\pandas\core\index.py:4281: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   return np.sum(name == np.asarray(self.names)) > 1

# %% [markdown]
# #Filter spurious trajectories

# %%
#The convenience function filter_stubs keeps only trajectories that last for a given number of frames.
minframes = 3
t1 = tp.filter_stubs(t, minframes)

# Compare the number of particles in the unfiltered and filtered data.
print('Before:', t['particle'].nunique())
print('After:', t1['particle'].nunique())
# Out:
# Before: 12
# After: 4

# %% [markdown]
# The basic walkthrough has been updated and now shows a different way to filter out particles by size. It has a few alternative/additional filtering options.

# %% [markdown]
# #Trace the tracjectories

# %%
plt.figure();
plt.title("Trajectories of Tracked Particles");
tp.plot_traj(t1);
# Out:
# C:\Anaconda3\lib\site-packages\pandas\core\index.py:4281: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   return np.sum(name == np.asarray(self.names)) > 1

# %% [markdown]
# #Velocity field

# %%
#Calculations
data = pd.DataFrame()
for item in set(t.particle):
    sub = t[t.particle==item]
    dvx = np.diff(sub.x)
    dvy = np.diff(sub.y)
    for x, y, dx, dy, frame in zip(sub.x[:-1], sub.y[:-1], dvx, dvy, sub.frame[:-1],):
        data = data.append([{'dx': dx, 'dy': dy, 'x': x,'y': y,'frame': frame,'particle': item,}])

# %%
#Rendering
i = 0
d = data[data.frame==i]
plt.imshow(rawcropped[i])
plt.quiver(d.x, d.y, d.dx, -d.dy, pivot='middle', headwidth=4, headlength=6, color='red')
plt.axis('off')
plt.title("Instantaneous Velocity at a Frame");
# Out:
# C:\Anaconda3\lib\site-packages\skimage\util\dtype.py:111: UserWarning: Possible precision loss when converting from float64 to int16
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# C:\Anaconda3\lib\site-packages\matplotlib\collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %% [markdown]
# #Remove overall drift

# %%
#Compute Drift
d = tp.compute_drift(t1)

# %%
d.plot();
plt.title("Overall Drift");

# %%
#Subtract Drift
tm = tp.subtract_drift(t1, d)

# %%
plt.figure();
plt.title("Driftless Trajectories");
tp.plot_traj(tm);
# Out:
# C:\Anaconda3\lib\site-packages\pandas\core\index.py:4281: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   return np.sum(name == np.asarray(self.names)) > 1
